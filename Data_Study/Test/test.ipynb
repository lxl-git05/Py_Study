# %%
a = 1
print(f"hello : {a}")
# Out:
# hello : 1

# %% [markdown]
# ## 1.1 添加md格式文件

# %%
a = 3

# %%
print(a)
# Out:
# 3

# %% [markdown]
# ## 1.2 快捷键
# 快捷键
# Shift + Enter === 运行当前单元格并跳到下一个
# Ctrl  + Enter === 运行当前单元格
# Alt + Enter   === 运行并在下面新建单元格
# A 在上方插入单元格
# B 在下方插入单元格
# DD删除当前单元格
# Z 撤销删除

# %%
print('hello world')
# Out:
# hello world

# %%
a = 20260219
print(a)

# %%
b = 2
print(b)
# Out:
# 2

# %%
c = 2026
print(c)
# Out:
# 2026
